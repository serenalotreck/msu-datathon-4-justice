# %% [markdown]
# # Name Parsing of the Call Takers
#
# Author: <i>Jamell Dacon</i>
#
# This notebook takes dictionary of "fuzzy names" and matches them to correctly spelt names

# %%
#!pip install fuzzywuzzy

# %%
from fuzzywuzzy import fuzz, process
import pandas as pd
import numpy as np
# Out:
# /mnt/home/daconjam/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
name_dict = {
'PATROL CRAIG A EICHHAMMER': 391,
 'PATROL DAVID JENNINGS, D': 1850,
 'DISPATCHER CHRISTINE LEMOINE': 508,
 'CHIEF KYLE J JOHNSON': 766,
 'PATROL KALVIN DZIEDZIAK': 1315,
 'PATROL JOHN J MCCONNELL JR': 1020,
 'PATROL KEVIN P GARNER': 639,
 'PATROL SHUAN N WILLIAM': 993,
 'SERGEANT PAUL D THOMPSON': 306,
 'PATROL ANTHONY M DUPRAT': 756,
 'PATROL TANIA HERNANDEZ': 2162,
 'PATROLMAN MICHAEL J ZIEMBA Jr': 542,
 'SERGEANT DAVID R LEMIEUX': 763,
 'DISPATCHER LAURIE TOPER': 161,
 'PATROLMAN SCOTT SKORUPSKI': 515,
 'DISPATCHER WILLIAM C JENNINGS JR': 505,
 'PATROL KAlVIN DZIEDZIAK': 1,
 'PATROLMAN MICBAEL J ZIEMBA Jr': 2,
 'SERGEANT SCOTT E MCGOWAN': 1496,
 'DISPATCHER LAURIE TUPER': 994,
 'PATROL CRAIG A EICIIHAMMER': 2,
 'ALL EQUIPMENT POLICE DEPARTMENT': 150,
 "PATROL DAVID JENNINGS,' D": 1,
 'SERGEANT jlCOTT E MCGOWAN': 1,
 'PATROLMAN MICHAELJ ZIEMBA Jr': 7,
 'PATROLMAN SCOIT SKORUPSKI': 4,
 'PATROL CRAIG A EIC!IHAMMER': 1,
 'PATROL CRAIG A EICHHI\\MMER': 3,
 'PATROL CRAIG A EIC!ffiAMMER': 1,
 "' DISPATCHER LAURIE TUPER": 1,
 'PATROL JOHN J MCCONNELLJR': 18,
 'CHIEF KYLE J JQHNSON': 1,
 "SERGEANT SCOTI' E MCGOWAN": 9,
 'PATROL CRAIG A EIClll!AMMER': 1,
 'PATROL ANTHONYM DUPRAT': 33,
 'PATROL CRAIG A EICIIHI\\MMER': 1,
 'FATROL SHUAN N WILLIAM': 1,
 'SERGEANT SCOTI E MCGOWAN': 18,
 'PATROL S!WAN N WILLIAM': 1,
 'PATROL CRAIG A EICHHl\\MMER': 1,
 'PATROLMMI MICHAEL J ZIEMBA Jr': 1,
 'PATROL BRAD SACCO': 1370,
 'DISPATCHER LAURIE TIJPER': 9,
 'PATROL CRAIG A EICHIIAMMER': 3,
 'PATROL CRAIG A EICHID\\MMER': 1,
 'PATROL SH\\JAN N WILLIAM': 1,
 'MICHAEL STRIZZI': 269,
 'SERGEANT SCOTT E MCGCWAN': 4,
 'DISPATCHER LAURm TUPER': 1,
 "PATROLMAN SCO'IT SKORUPSKI": 2,
 'PATROL SHUAN N WILLU\\M': 1,
 'PATROL SHU.ANN WILLIAM': 9,
 'DISPATCHER V-lILLIAM C JENNINGS JR': 1,
 'PATROL DAVID JENN"INGS, D': 1,
 'PATROL TANIA HERNAf,,TDEZ': 1,
 'PATROLMAN MICHAEL ,J ZIEMBA Jr': 1,
 "PATROLMAN SCOT!' SKORUPSKI": 5,
 'PATROL SHUAN N lHLLIAM': 1,
 'DISPATCHER LAURIE 1UPER': 1,
 'PATROL KALVIN DZIEOZIAK': 4,
 'PATROL JO!rn J MCCONNELL JR': 1,
 'PATROL SHUM N WILLIAM': 1,
 'SERGEAN"T DAVID R LEMIEUX': 1,
 "SERGEANT SCO'IT E MCGOWAN": 9,
 'MICHAEL STRIZZl': 1,
 'PATROL JOHN" J MCCONNELL JR': 2,
 'PATROL TANIA HERNANPEZ': 1,
 'PATROL SHUA!il N WILLIAM': 1,
 'PATROL KEVIN P GAR.~ER': 1,
 'PATROLMAN SCOTI SKORUPSKI': 5,
 'DISPATCHER WILLIA.~ C JENNINGS JR': 1,
 "SERGEANT SCOT!' E MCGO~IAN": 1,
 'PATROL CRAIG A EICHH_l\\MMER': 1,
 'MICHAEL STRIZZ!': 1,
 'ALL EQUIPMENT POLICE DEPAR™ENT': 2,
 'PATROL CRAIG A EICHF.AMMER': 1,
 "PATROU'1AN MICHAELJ ZIEMBA Jr": 1,
 "PATROL TANIA HERNA.'IDEZ": 1,
 "PATROL DAVID JENN'INGS, D": 2,
 'PATROL SIDJAN N WILLIAM': 1,
 "PATROLMAN SCOTI' SKORUPSKI": 2,
 'SERGEANT SCOTT E MCGO>~AN': 1,
 "PATROL ANTHONY 1'>1 DUPRAT": 1,
 "PATROL TANIA HERNAh'lJEZ": 1,
 "PATROL TANIA HERNA..'IDEZ": 1,
 'PATROLMAN MICRAEL J ZIEMBA Jr': 1,
 'PATROL DAVID JENNIKGS, D': 1,
 'PATROL SHUAN"N WILLIAM': 1,
 'PATROL SHUAN N ~IILLIAM': 1,
 'PATROL SHUM! N WILLIAM': 3,
 'DISPATCHER LAURIE T"JPER': 2,
 'LIEUTENANT MICHAEL J ZIEMBA Jr': 446,
 'PATROL DAVID JENNINGS, 0': 2,
 'SERGEANT PAUL D THCMPSON': 1,
 'LIEUTENANT MICHAEL J ZIEMBAJr': 1,
 'PATROL JOI-rn J MCCONNELL JR': 1,
 'PATROL TANIA HER.~ANDEZ': 1,
 'SERGEANT PAUL D TIIOMPSON': 1,
 'SERGEANT SCOTT E MCGmlAN': 1,
 'PATROL ANTHONY M CUPRAT': 2,
 'PATROL JOHN J MCCO~"NELL JR': 1,
 "SERGEANT SCOTI E MCGOWAN'": 1,
 "PATROL JOHN J MCCONl'JELL JR": 1,
 'LIEUTENANT MICHAEL J" ZIEMBA Jr': 1,
 "SERGEANT SCOTT E MCGOl'i'AN": 1,
 'PATROL JOJrn J MCCONNELL JR': 2,
 'PATROL CRAIG A EICHHAMI<IER': 1,
 'PATROL TANIA HERN~.NDEZ': 1,
 "DISPATCHER LAURIE 'I'UPER": 1,
 'PATROL KALVIN OZIEDZIAK': 4,
 "DISPATCHER \\'IILLIAM C JENNINGS JR": 1,
 'DISPATCHER LA.URIE TUPER': 1,
 "PATROL SHUAN N l'l'ILLIAM": 1,
 'PATROL TANIA HERNAfIDEZ': 1,
 'LIEUTRNANT MICHAEL J ZIEMBA Jr': 1,
 'SERGEANT SCOTT E MCGOl\x7fJAN': 1,
 'LIEUTENANT MICHA.EL J ZIEMBA Jr': 1,
 'CHIEF KYLE J JOIDilSON': 1,
 'DISPATCHER LAURIE 7UPER': 1,
 "CHIEF KYLE J JOHNSO!'f": 1,
 'LIEUTENANT MICHAELJ ZIEMBA Jr': 12,
 'LIEUTENANT MICHA.ELJ ZIEMBA Jr': 1,
 "CHIEF k'YLE J JOHNSON": 1,
 'SERGEAl<T PAUL D THOMPSON': 1,
 "SERGEANT SCOT!' E MCGOWAN": 1,
 'PATROL JOIDI J MCCONNELL JR': 1,
 'DISPATCHER LAURIE TGPER': 1,
 "DISPATCHER LAURIE 'l'UPER": 2,
 "SERGEANT SCOTT E MCGOWAN'": 1,
 'FATROL TANIA HERNANDEZ': 1,
 'PATROL SHUAN N ~lILLIAM': 1,
 "PATROL SHUAN N \\'l'ILLIAM": 1,
 'DISJ?ATCHER CHRISTINE LEMOINE': 1,
 'SERGE~.NT DAVID R LEMIEUX': 1,
 'SERGEANT SCOTT E MCGOWAN"': 4,
 'CHIEF KYLE J JOHNSO~': 1,
 'PATROL SHUAN N IHLLIAM': 2,
 'PATROL SHOAN N WILLIAM': 2,
 'SERGEANT SCOTT E MCGO~IAN': 1,
 'SERGEANT SCOTT E ~CGOWAN': 1,
 "PATROL TANIA HERNAf..'DEZ": 1,
 'PATROL TANIA HERNJl..NOEZ': 1,
 'PATROL SHUAN N IULLIAM': 2,
 'SERGEANT SCOIT E MCGO\\flAN': 1,
 'PATROL TANJA HERNANDEZ': 1,
 'PATROL JOHN J MCCONN"ELL JR': 1,
 'PATROL KEVIN p GARNER': 2,
 "PATROL TANIA HERNAN'DEZ": 1,
 "LIEUTENANT MICHAEL J' ZIEMBA Jr": 2,
 'SERGEANT PAUL D TI!CMPSON': 1,
 'CHIEF KYLE J JOfillSON': 1,
 "CHIEF KYLE J JOHNSON'": 1,
 "DISPATCHER l'HLLIAf~ C JENNINGS JR": 1,
 'PATROL KALVIN DZIEDZlAK': 1,
 'PATROL KALVIN DZIEDZ!AK': 1,
 'PATROL TANIA HERNANCEZ': 1,
 "PATROL SHUAN N l'lILLIAM": 1,
 'SERGEANT DAVID R LE~IEUX': 1,
 'PATROL AflTHONY M DUPRAT': 1,
 'PATROL SHUAiil N WILLIAM': 1,
 "PATROLMAN SCOTT' SKORUPSKI": 2,
 '?ATROL KALVIN DZIEDZIAK': 1,
 'PATROL JOIDi J MCCONNELL JR': 1,
 'SERGEANT SCOTT E M2GOWAN': 1,
 'PATROL TANIA HERNA.~DEZ': 1,
 'PATROL SHUAN N WILf~IAM': 1,
 'PATROL KEVIN I? GARNER': 1,
 "SERGEANT SCOTT' E MCGOWAN": 1,
 'SERGEANT SCOTT E MCG0~1AN': 1,
 "SERGEANT SCOTT E MCGOl'-lAN": 1,
 'PATROL BAAD SACCO': 1,
 'LIEUTENANT MICHAEL ,J ZIEMBA Jr': 1,
 "DISPATCHER LAURIE 'ruPER": 1,
 "DISPATCHER LAURIE 1'UPER": 1,
 "SERGEANT SCOTT E MCGOl'lAN": 1,
 'PATROL TANIA HERNA.,.~EZ': 1,
 'PATROL SHUAlil N WILLIAM': 1,
 'PATROL TANIA HERNAfJDEZ': 1,
 'PATROL ANTHONYM DUJ?RAT': 1,
 "PATROL TANIA HERl'JANDEZ": 1,
 'DISPATCHER LAURIE ·ruPER': 1,
 "PATROL SHUAN N l'IILLIAM": 1,
 'SERGBANT SCOTT E MCGOWAN': 1,
 'PATROL JOIIlil J MCCONNELL JR': 1,
 'PATROL JOHN J MCCCNNELL JR': 1,
 'PATROL TAN"IA HERNAN"DEZ': 1,
 'PATROL TANIA HERNAN"DEZ': 1,
 'DISPATCHER LAUR.IE TOPER': 1,
 'CHIEF KYLE J JQH](fSON': 1,
 'CHIEF KYLE J JOH](fSON': 1,
 'SERGEANT DAVID R LEMIEDX': 1,
 'PATROL TANIA HERNANOEZ': 2,
 'PATROL CRAIG A EIC!IllAMMER': 1,
 'BARB BRUCATO': 95,
 'PATROL CRAIG A EIC!ll!AMMER': 1,
 'BARB BROCATO': 1,
 'LIEUTENANI MICHAEL J ZIEMBA Jr': 1,
 'PAT~OL JOHN J MCCONNELL JR': 1,
 'PATROL SHlJAN N WILLIAM': 2,
 'SERGEANT SCOIT E MCGOWAN': 4,
 'PATROL CRAIG A EICHl!AMMER': 1,
 'SERGEANT SCOTr E MCGOWAN': 1,
 'PATROL BRAO SACCO': 2,
 "SERGEANT SCO'.IT E MCGOWAN": 1,
 'DISPATCHER LAURIE WPER': 3,
 'PATROL CRAIG A EIC!Il!AMMER': 1,
 'PATROL CRAIG A EICIIl!AMMER': 1,
 'PATROL SITTJANN WILLIAM': 1,
 'PATROL SHUANN WILLIAM': 1}

name_dict = {k: v for k, v in sorted(name_dict.items(), key=lambda item: item[1], reverse=True)}
#name_dict = {k: v for k, v in sorted(name_dict.items(), key=lambda item: item[1])}

# %%
df = pd.DataFrame()

names, count = [], []

for k,v in name_dict.items():
    names.append(k)
    count.append(v)
    
    
df['Call Taker'] = names
df['Count'] = count

print(df.shape)
df.head(20)
# Out:
# (209, 2)
#                           Call Taker  Count
# 0             PATROL TANIA HERNANDEZ   2162
# 1           PATROL DAVID JENNINGS, D   1850
# 2           SERGEANT SCOTT E MCGOWAN   1496
# 3                  PATROL BRAD SACCO   1370
# 4            PATROL KALVIN DZIEDZIAK   1315
# 5         PATROL JOHN J MCCONNELL JR   1020
# 6            DISPATCHER LAURIE TUPER    994
# 7             PATROL SHUAN N WILLIAM    993
# 8               CHIEF KYLE J JOHNSON    766
# 9           SERGEANT DAVID R LEMIEUX    763
# 10           PATROL ANTHONY M DUPRAT    756
# 11             PATROL KEVIN P GARNER    639
# 12     PATROLMAN MICHAEL J ZIEMBA Jr    542
# 13         PATROLMAN SCOTT SKORUPSKI    515
# 14      DISPATCHER CHRISTINE LEMOINE    508
# 15  DISPATCHER WILLIAM C JENNINGS JR    505
# 16    LIEUTENANT MICHAEL J ZIEMBA Jr    446
# 17         PATROL CRAIG A EICHHAMMER    391
# 18          SERGEANT PAUL D THOMPSON    306
# 19                   MICHAEL STRIZZI    269

# %%
top_names = ["TANIA HERNANDEZ",
"DAVID JENNINGS, D",
"SCOTT E MCGOWAN",
"BRAD SACCO",
"KALVIN DZIEDZIAK",
"JOHN J MCCONNELL JR",
"LAURIE TUPER",
"SHUAN N WILLIAM",
"KYLE J JOHNSON",
"DAVID R LEMIEUX",
"ANTHONY M DUPRAT",
"KEVIN P GARNER",
"MICHAEL J ZIEMBA Jr",
"SCOTT SKORUPSKI",
"CHRISTINE LEMOINE",
"WILLIAM C JENNINGS JR",
"MICHAEL J ZIEMBA Jr",
"CRAIG A EICHHAMMER",
"PAUL D THOMPSON",
"MICHAEL STRIZZI",
"LAURIE TOPER",
"ALL EQUIPMENT POLICE DEPARTMENT",
"BARB BRUCATO"]

# %%
df['Fuzzy Names'] = ''

def fuzz_match():
    matched = []
    rank_list = ["CHIEF", "PATROL", "FATROL", "DISPATCHER", "SERGEANT", "LIEUTENANT", "'", "PATROLMMI", "PATROLMAN",
                'SERGEAN"T', "PATROU'1AN", "LIEUTRNANT", "SERGEAl<T", "DISJ?ATCHER", "SERGE~.NT", "?ATROL", "SERGBANT",
                "PAT~OL", "LIEUTENANI", ]
    for i, names in enumerate(df['Call Taker']): 
        name = names.split()

        rank = [rank for rank in rank_list if name[0] in rank]
        for r in rank:
            if r in name:
                name.remove(r)
            continue

        name = ' '.join(name)
            
        df.loc[i, 'Fuzzy Names'] = name

        highest = process.extractOne(name,top_names)
        match = highest[0]

        df.loc[i, 'Matched'] = match

# %%
fuzz_match()

# %%
df.head(20)
# Out:
#                           Call Taker  Count            Fuzzy Names  \
# 0             PATROL TANIA HERNANDEZ   2162        TANIA HERNANDEZ
# 1           PATROL DAVID JENNINGS, D   1850      DAVID JENNINGS, D
# 2           SERGEANT SCOTT E MCGOWAN   1496        SCOTT E MCGOWAN
# 3                  PATROL BRAD SACCO   1370             BRAD SACCO
# 4            PATROL KALVIN DZIEDZIAK   1315       KALVIN DZIEDZIAK
# 5         PATROL JOHN J MCCONNELL JR   1020    JOHN J MCCONNELL JR
# 6            DISPATCHER LAURIE TUPER    994           LAURIE TUPER
# 7             PATROL SHUAN N WILLIAM    993        SHUAN N WILLIAM
# 8               CHIEF KYLE J JOHNSON    766         KYLE J JOHNSON
# 9           SERGEANT DAVID R LEMIEUX    763        DAVID R LEMIEUX
# 10           PATROL ANTHONY M DUPRAT    756       ANTHONY M DUPRAT
# 11             PATROL KEVIN P GARNER    639         KEVIN P GARNER
# 12     PATROLMAN MICHAEL J ZIEMBA Jr    542    MICHAEL J ZIEMBA Jr
# ...

# %%
dict_ = {}

for name in df['Matched']:
    if name not in dict_:
        dict_[name] = 1
        
    dict_[name] += 1

# %%
print('Number of call takers are {}.'.format(len(dict_)))
print(dict_)
# Out:
# Number of call takers are 22.
# {'TANIA HERNANDEZ': 23, 'DAVID JENNINGS, D': 7, 'SCOTT E MCGOWAN': 28, 'BRAD SACCO': 4, 'KALVIN DZIEDZIAK': 8, 'JOHN J MCCONNELL JR': 14, 'LAURIE TUPER': 16, 'SHUAN N WILLIAM': 28, 'KYLE J JOHNSON': 12, 'DAVID R LEMIEUX': 6, 'ANTHONY M DUPRAT': 7, 'KEVIN P GARNER': 5, 'MICHAEL J ZIEMBA Jr': 18, 'SCOTT SKORUPSKI': 8, 'CHRISTINE LEMOINE': 3, 'WILLIAM C JENNINGS JR': 6, 'CRAIG A EICHHAMMER': 19, 'PAUL D THOMPSON': 6, 'MICHAEL STRIZZI': 4, 'LAURIE TOPER': 3, 'ALL EQUIPMENT POLICE DEPARTMENT': 3, 'BARB BRUCATO': 3}
