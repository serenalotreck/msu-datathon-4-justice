# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
MN = pd.read_csv("allmn.csv")
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (45,46) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
MN.shape
# Out:
# (294467, 81)

# %%
# removes samples that contain NANs from a subset of the data 
def drop_nan(col_names, data):
    # data    : original dataframe
    # col_ids : column ids for the clean(no-nan) sub_dataset
    sub_data = data[col_names].dropna()
    return(sub_data)
    
# get sub_data and find correlation
sub = drop_nan(MN.columns,MN)
sub_corr = sub.corr()
sub.shape
# Out:
# (81589, 81)

# %%
def make_meta_map():
    # read in the data
    df_meta = pd.read_excel('MNCodebook.xlsx',sheet_name='Variable Values',skiprows=1)
    df_meta = df_meta.fillna(method='ffill')
    # initialize the dictionary
    meta_map = {}
    # populate dictionary
    for idx in range(df_meta.shape[0]):
        name_tmp = df_meta.iloc[idx,0]
        if name_tmp == 'Offense':
            value_tmp = float(df_meta.iloc[idx,1])
        else:
            value_tmp = int(df_meta.iloc[idx,1])
        label_tmp = df_meta.iloc[idx,2]
        if name_tmp not in list(meta_map):
            meta_map[name_tmp] = {}
        meta_map[name_tmp][value_tmp] = label_tmp 
    return meta_map
meta_map = make_meta_map()

# %%
full_cols = list(MN)
for acol in full_cols:
    coldata = MN[acol]
    if coldata.dtype != "object":
        fig, ax = plt.subplots(figsize=(8,8))
        if acol in list(meta_map):
            sns.countplot(coldata)
        else:
            sns.boxplot(coldata)
        ax.set_title(acol)
        plt.show()
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
def make_autopct(values):
    def my_autopct(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '{p:.2f}%  ({v:d})'.format(p=pct,v=val)
    return my_autopct

# %%
count = []
index = np.unique(MN["sentyear"])
for j in index:
    count.append(len(MN["sentyear"][MN["sentyear"]==j]))
plt.pie(count, labels=index, autopct='%1.1f%%')
plt.title("sentyear")
# Out:
# Text(0.5, 1.0, 'sentyear')

# %%
count = []
index = np.unique(MN["district"])
for j in index:
    count.append(len(MN["district"][MN["district"]==j]))
plt.pie(count,labels=index, autopct='%1.1f%%')
plt.title("district")
# Out:
# Text(0.5, 1.0, 'district')

# %%
plt.hist(MN["county"])
plt.title("county")
# Out:
# Text(0.5, 1.0, 'county')

# %%
print(np.mean(MN["count"]))
plt.plot(MN["count"])
# Out:
# 1.3162413190022584

# %%
fig,ax = plt.subplots(2,1,figsize=(8,8))
sns.boxplot(MN["confine"],ax=ax[0]) # showfliers=False, notch=True
sns.histplot(MN["confine"], ax=ax[1])
plt.tight_layout()
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig,ax = plt.subplots(1,1,figsize=(8,8))
count = []
index = np.unique(MN["sex"])
for j in index:
    count.append(len(MN["sex"][MN["sex"]==j]))
plt.pie(count, labels=index, autopct=make_autopct(count))
plt.title("sex")
# Out:
# Text(0.5, 1.0, 'sex')

# %%
fig,ax = plt.subplots(1,1,figsize=(8,8))
racecount = []
index = np.unique(MN["race"])
for j in index:
    racecount.append(len(MN["race"][MN["race"]==j]))
plt.pie(racecount, labels=index, autopct=make_autopct(racecount))
plt.title("race")
# Out:
# Text(0.5, 1.0, 'race')

# %%
fig,ax = plt.subplots(1,1,figsize=(8,8))
agecount = []
index = np.unique(MN["Agecat"])
for j in index:
    agecount.append(len(MN["Agecat"][MN["Agecat"]==j]))
plt.pie(agecount,labels=index, autopct='%1.1f%%')
plt.title("Agecat")
# Out:
# Text(0.5, 1.0, 'Agecat')

# %%
fig,ax = plt.subplots(2,1,figsize=(8,8))
sns.boxplot(MN["gangrel"][MN["gangrel"]==0],MN["confine"], ax=ax[0], showfliers=False, notch=True)
sns.boxplot(MN["gangrel"][MN["gangrel"]==1],MN["confine"], ax=ax[1], showfliers=False, notch=True)
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gangrel', ylabel='confine'>

# %%
fig,ax = plt.subplots(1,1,figsize=(8,8))
count = []
index = np.unique(MN["jail"])
for j in index:
    count.append(len(MN["jail"][MN["jail"]==j]))
plt.pie(count,labels=index, autopct='%1.1f%%')
plt.title("Jail")
# Out:
# Text(0.5, 1.0, 'Jail')

# %%
fig,ax = plt.subplots(1,1,figsize=(8,8))
count = []
index = np.unique(MN["severity"])
for j in index:
    count.append(len(MN["severity"][MN["severity"]==j]))
plt.pie(count,labels=index, autopct='%1.1f%%')
plt.title("severity")
# Out:
# Text(0.5, 1.0, 'severity')

# %%
fig,ax = plt.subplots(1,1,figsize=(8,8))
count = []
index = np.unique(MN["offtype"])
for j in index:
    count.append(len(MN["offtype"][MN["offtype"]==j]))
plt.pie(count,labels=index, autopct='%1.1f%%')
plt.title("offtype")
# Out:
# Text(0.5, 1.0, 'offtype')

# %%
gang18=MN[MN["gangrel18"]==1]

# %%
gang=MN[MN["gangrel"]==1]

# %%
sent = MN[MN["confine"]>0]
notserved=sent[sent["jail"]==0][sent["prison"]==0]
# Out:
# <ipython-input-140-04951b405182>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   notserved=sent[sent["jail"]==0][sent["prison"]==0]

# %%
fig,ax = plt.subplots(1,1,figsize=(8,8))
racecount = []
index = np.unique(notserved["race"])
for j in index:
    racecount.append(len(notserved["race"][notserved["race"]==j]))
plt.pie(racecount, labels=index, autopct=make_autopct(racecount))
plt.title("Race")
# Out:
# Text(0.5, 1.0, 'Race')

# %%
sum(notserved["confine"])/len(notserved["confine"])
# Out:
# 23.29453028830618

# %%
sum(sub["confine"])/len(sub["confine"])
# Out:
# 21.057653850398104

# %%
sns.countplot(notserved["severity"])
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='severity', ylabel='count'>

# %%
sns.countplot(notserved["offtype"])
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='offtype', ylabel='count'>

# %%
sns.countplot(notserved["race"])
plt.title("Race count versus notserved people")
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Race count versus notserved people')

# %%
sns.countplot(notserved["Agecat"])
plt.title("Age category among notserved people")
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Age category among notserved people')

# %%
sns.boxplot(notserved["confine"], showfliers=False, notch=True)
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='confine'>

# %%
sns.boxplot(notserved["time"],showfliers=False, notch=True)
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='time'>

# %%
sns.countplot(gang18["race"])
plt.title("Race proportion among gang related and under age 18")
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Race proportion among gang related and under age 18')

# %%
sns.countplot(gang["race"])
plt.title("Race proportion among gang related")
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Race proportion among gang related')

# %%
sum(notserved["gangrel18"]==1)
# Out:
# 1

# %%
sns.countplot(MN["Agecat"])
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Agecat', ylabel='count'>

# %%
white = MN[MN["race"]==2]
black = MN[MN["race"]==2]
asian = MN[MN["race"]==5]

# %%
fig,ax = plt.subplots(3,1, figsize=(8,8))
sns.boxplot(white["confine"], ax=ax[0])
sns.boxplot(black["confine"], ax=ax[1])
sns.boxplot(asian["confine"], ax=ax[2])
plt.tight_layout()
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Gang percentage on each county/district

# %%
sum(MN["plea"]==1)
# Out:
# 284847

# %%
sum(MN["plea"]==2)
# Out:
# 9620

# %%
MN["plea"].unique()
# Out:
# array([1, 2], dtype=int64)

# %%
len(MN["jfname"].unique())
# Out:
# 571

# %%
MN["fullname"] = MN["jfname"]+MN["jlname"]

# %%
judge_guilt = {}
for j in MN["fullname"].unique():
    judge = MN[MN["fullname"]==j]
    judge_guilt[j] = (sum(judge["plea"]==1),sum(judge["plea"]==2))

# %%
len(judge_guilt.keys())
# Out:
# 720

# %%
len(MN["county"].unique())
# Out:
# 87

# %%
MN["gangrel"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
county_names = pd.read_csv("countycodes.csv",header=None)
county_names.head()
# Out:
#    0         1
# 0  1    Aitkin
# 1  2     Anoka
# 2  3    Becker
# 3  4  Beltrami
# 4  5    Benton

# %%
county_order = county_names[1].to_numpy()
result=[]
for i,name in enumerate(county_order):
    value = gang_county[i+1]
    result.append([name,value])
pd.DataFrame(result, columns=["County","Count"]).to_csv('allgang_county.csv', header=True, index=0)

# %%
gang_dist = []
for d in MN["district"].unique():
    district = MN[MN["district"]==d]
    gang_dist.append([d,sum(district["gangrel"])+sum(district["gangrel18"])])
pd.DataFrame(gang_dist, columns=["Dist","Count"]).to_csv('allgang_dist.csv', header=True, index=0)

# %%
gang_county = {}
for d in MN["county"].unique():
    county = MN[MN["county"]==d]
    gang_county[d]= sum(county["gangrel"])+sum(county["gangrel18"])
gang_county
# Out:
# {42: 0,
#  2: 8,
#  3: 0,
#  4: 1,
#  10: 5,
#  14: 0,
#  15: 0,
#  19: 1,
#  27: 69,
#  28: 0,
#  49: 0,
#  50: 0,
#  58: 0,
#  62: 85,
#  66: 1,
#  70: 4,
#  76: 0,
#  81: 0,
#  82: 1,
#  86: 0,
#  1: 0,
#  7: 2,
#  9: 2,
#  18: 1,
#  30: 0,
#  31: 0,
#  34: 3,
#  48: 0,
#  51: 0,
#  55: 2,
#  56: 0,
#  69: 2,
#  73: 3,
#  75: 0,
#  77: 0,
#  5: 0,
#  11: 4,
#  13: 1,
#  21: 1,
#  46: 0,
#  60: 0,
#  65: 0,
#  79: 0,
#  85: 1,
#  24: 0,
#  25: 0,
#  26: 0,
#  43: 0,
#  64: 1,
#  68: 0,
#  71: 0,
#  74: 0,
#  87: 0,
#  17: 0,
#  72: 0,
#  47: 1,
#  20: 0,
#  33: 0,
#  53: 1,
#  78: 0,
#  84: 0,
#  29: 0,
#  36: 0,
#  44: 0,
#  52: 1,
#  57: 0,
#  12: 0,
#  54: 0,
#  8: 0,
#  80: 0,
#  40: 0,
#  32: 0,
#  22: 0,
#  61: 0,
#  16: 0,
#  37: 0,
#  45: 0,
#  38: 0,
#  39: 0,
#  23: 0,
#  59: 0,
#  83: 0,
#  63: 0,
#  35: 0,
#  6: 0,
#  67: 0,
#  41: 0}

# %%
dist_notserved = []
for d in MN["district"].unique():
    district = MN[MN["district"]==d]
    dist_notserved.append([d,round(((len(district[district["jail"]!=100][district["prison"]!=100]))/len(district))*100,4)])
dist_notserved
pd.DataFrame(dist_notserved, columns=["Dist","Percentage"]).to_csv('notserved_dist.csv', header=True, index=0)
# Out:
# <ipython-input-112-a826d001a864>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dist_notserved.append([d,round(((len(district[district["jail"]!=100][district["prison"]!=100]))/len(district))*100,4)])
# <ipython-input-112-a826d001a864>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dist_notserved.append([d,round(((len(district[district["jail"]!=100][district["prison"]!=100]))/len(district))*100,4)])
# <ipython-input-112-a826d001a864>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dist_notserved.append([d,round(((len(district[district["jail"]!=100][district["prison"]!=100]))/len(district))*100,4)])
# <ipython-input-112-a826d001a864>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   dist_notserved.append([d,round(((len(district[district["jail"]!=100][district["prison"]!=100]))/len(district))*100,4)])
# ...

# %%
MN["gangrel"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
sub = MN[MN["county"]==11]
sub_gang = sub[(sub["gangrel"]==1)|(sub["gangrel"]==1)]
sns.countplot(sub_gang["race"],order=[1,2,3,4,5])
plt.title("Gang related case race count in Cass county")
sum(sub_gang["confine"])/len(sub_gang["confine"])
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 228.5

# %%
sub = MN[MN["county"]==27]
sub_gang = sub[(sub["gangrel"]==1)|(sub["gangrel"]==1)]
sns.countplot(sub_gang["race"],order=[1,2,3,4,5])
plt.title("Gang related case race count in Hennepin county")
sum(sub_gang["confine"])/len(sub_gang["confine"])
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 117.79980769230768

# %%
sub = MN[MN["county"]==62]
sub_gang = sub[(sub["gangrel"]==1)|(sub["gangrel"]==1)]
sns.countplot(sub_gang["race"],order=[1,2,3,4,5])
plt.title("Gang related case race count in Ramsey county")
sum(sub_gang["confine"])/len(sub_gang["confine"])
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 99.63361111111111

# %%
MN[(MN["gangrel"]==1)|(MN["gangrel18"]==1)]
# Out:
#         sentyear  district  county       dcnum  count  sentord  order  sex  \
# 36463       2017         4      27   CR1616756    1.0      1.0    1.0    1
# 37567       2017         4      27         NaN    1.0      1.0    1.0    1
# 38053       2017         2      62    CR163690    3.0      2.0    1.0    1
# 46838       2017         2      62    CR162912    5.0      1.0    1.0    1
# 46869       2017         2      62    CR162998    1.0      1.0    1.0    1
# ...          ...       ...     ...         ...    ...      ...    ...  ...
# 291414      2001         2      62         NaN    2.0      1.0    1.0    1
# 291415      2001         2      62  K899003527    4.0      1.0    1.0    1
# 293885      2001         6      69  K000600496    1.0      2.0    1.0    1
# 294418      2001         6      69  K200600502    1.0      1.0    1.0    1
# 294451      2001         7      73  K200001367    2.0      2.0    1.0    1
#
# ...

# %%
gang_rel = MN[(MN["gangrel"]==1)|(MN["gangrel18"]==1)]
sns.countplot(gang_rel["race"])
plt.title("Gang related cases by race")
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gang related cases by race')

# %%
gang_rel = MN[(MN["gangrel"]==1)]
sns.countplot(gang_rel["race"])
plt.title("Gang (over18) related cases by race")
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gang (over18) related cases by race')

# %%
gang_rel = MN[(MN["gangrel18"]==1)]
sns.countplot(gang_rel["race"], order=[1,2,3,4,5])
plt.title("Gang (under18) related cases by race")
# Out:
# C:\Users\narut\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Gang (under18) related cases by race')
